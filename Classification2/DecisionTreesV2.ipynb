# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %% [markdown]
# <h2> Hotel Reviews </h2>

# %%
hotel_reviews=pd.read_csv('hotels/hotel_reviews.csv')
hotel_reviews.head(3)
# Out:
#                   address categories      city country   latitude  longitude  \
# 0  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611  12.376187
# 1  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611  12.376187
# 2  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611  12.376187
#
#                  name postalCode province          reviews.date  \
# 0  Hotel Russo Palace      30126       GA  2013-09-22T00:00:00Z
# 1  Hotel Russo Palace      30126       GA  2015-04-03T00:00:00Z
# 2  Hotel Russo Palace      30126       GA  2014-05-13T00:00:00Z
#
#       reviews.dateAdded  reviews.doRecommend  reviews.id  reviews.rating  \
# 0  2016-10-24T00:00:25Z                  NaN         NaN             4.0
# 1  2016-10-24T00:00:25Z                  NaN         NaN             5.0
# 2  2016-10-24T00:00:25Z                  NaN         NaN             5.0
#
#                                         reviews.text  \
# 0  Pleasant 10 min walk along the sea front to th...
# 1  Really lovely hotel. Stayed on the very top fl...
# 2  Ett mycket bra hotell. Det som drog ner betyge...
#
#                         reviews.title reviews.userCity reviews.username  \
# 0  Good location away from the crouds              NaN      Russ (kent)
# 1      Great hotel with Jacuzzi bath!              NaN       A Traveler
# 2                         Lugnt l��ge              NaN             Maud
#
#   reviews.userProvince
# 0                  NaN
# 1                  NaN
# 2                  NaN

# %%
hotel_reviews=hotel_reviews[['reviews.text','reviews.rating']]
hotel_reviews
# Out:
#                                             reviews.text  reviews.rating
# 0      Pleasant 10 min walk along the sea front to th...             4.0
# 1      Really lovely hotel. Stayed on the very top fl...             5.0
# 2      Ett mycket bra hotell. Det som drog ner betyge...             5.0
# 3      We stayed here for four nights in October. The...             5.0
# 4      We stayed here for four nights in October. The...             5.0
# ...                                                  ...             ...
# 35907  Best of the Best!!!! My family and I stayed in...             5.0
# 35908  Amazing Vacation in Beautiful Cabin We stayed ...             5.0
# 35909  My husband and I stayed at Tree Tops which is ...             5.0
# 35910  to share your opinion of this businesswith YP ...             0.0
# 35911         xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx             0.0
#
# [35912 rows x 2 columns]

# %%
hotel_reviews.dropna(inplace=True)
hotel_reviews
# Out:
#                                             reviews.text  reviews.rating
# 0      Pleasant 10 min walk along the sea front to th...             4.0
# 1      Really lovely hotel. Stayed on the very top fl...             5.0
# 2      Ett mycket bra hotell. Det som drog ner betyge...             5.0
# 3      We stayed here for four nights in October. The...             5.0
# 4      We stayed here for four nights in October. The...             5.0
# ...                                                  ...             ...
# 35907  Best of the Best!!!! My family and I stayed in...             5.0
# 35908  Amazing Vacation in Beautiful Cabin We stayed ...             5.0
# 35909  My husband and I stayed at Tree Tops which is ...             5.0
# 35910  to share your opinion of this businesswith YP ...             0.0
# 35911         xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx             0.0
#
# [35028 rows x 2 columns]

# %%
hotel_reviews = hotel_reviews[(hotel_reviews['reviews.rating']>0) & (hotel_reviews['reviews.rating']<=5)]
hotel_reviews
# Out:
#                                             reviews.text  reviews.rating
# 0      Pleasant 10 min walk along the sea front to th...             4.0
# 1      Really lovely hotel. Stayed on the very top fl...             5.0
# 2      Ett mycket bra hotell. Det som drog ner betyge...             5.0
# 3      We stayed here for four nights in October. The...             5.0
# 4      We stayed here for four nights in October. The...             5.0
# ...                                                  ...             ...
# 35905  We truly enjoyed staying at the Elk Springs re...             5.0
# 35906  We were here for a 2nd time the last weekend o...             5.0
# 35907  Best of the Best!!!! My family and I stayed in...             5.0
# 35908  Amazing Vacation in Beautiful Cabin We stayed ...             5.0
# 35909  My husband and I stayed at Tree Tops which is ...             5.0
#
# [34334 rows x 2 columns]

# %%
avg_mask=hotel_reviews['reviews.rating']==3
pos_mask=hotel_reviews['reviews.rating']>3
neg_mask=hotel_reviews['reviews.rating']<3

# %%
pos_mask
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 35905    True
# 35906    True
# 35907    True
# 35908    True
# 35909    True
# Name: reviews.rating, Length: 34334, dtype: bool

# %%
hotel_reviews.loc[ avg_mask, 'reviews.rating'] ='avg'
hotel_reviews.loc[ pos_mask, 'reviews.rating'] ='pos'
hotel_reviews.loc[ neg_mask, 'reviews.rating'] ='neg'

# %%
hotel_reviews
# Out:
#                                             reviews.text reviews.rating
# 0      Pleasant 10 min walk along the sea front to th...            pos
# 1      Really lovely hotel. Stayed on the very top fl...            pos
# 2      Ett mycket bra hotell. Det som drog ner betyge...            pos
# 3      We stayed here for four nights in October. The...            pos
# 4      We stayed here for four nights in October. The...            pos
# ...                                                  ...            ...
# 35905  We truly enjoyed staying at the Elk Springs re...            pos
# 35906  We were here for a 2nd time the last weekend o...            pos
# 35907  Best of the Best!!!! My family and I stayed in...            pos
# 35908  Amazing Vacation in Beautiful Cabin We stayed ...            pos
# 35909  My husband and I stayed at Tree Tops which is ...            pos
#
# [34334 rows x 2 columns]

# %%
train_data, test_data = train_test_split(hotel_reviews, test_size=0.3)

# %%
train_text=train_data['reviews.text']
test_text=test_data['reviews.text']
train_labels=train_data['reviews.rating']
test_labels=test_data['reviews.rating']

# %%
#Build a counter based on the training dataset
counter = CountVectorizer()
counter.fit(train_text)


#count the number of times each term appears in a document and transform each doc into a count vector
counts_train = counter.transform(train_text)#transform the training data
counts_test = counter.transform(test_text)#transform the testing data

vocabulary=[x[0] for x in sorted(counter.vocabulary_.items(),key=lambda x:x[1])]

# %%
counter.vocabulary_.items()
# Out:
# dict_items([('couldn', 5967), ('sleep', 21736), ('because', 2872), ('of', 16452), ('ac', 837), ('unit', 24925), ('banging', 2642), ('all', 1374), ('night', 16055), ('breakfast', 3643), ('for', 9702), ('disappointing', 7176), ('to', 24019), ('say', 20698), ('the', 23728), ('lease', 13729), ('trays', 24389), ('were', 26202), ('empty', 8210), ('nobody', 16102), ('around', 2017), ('refill', 19381), ('foods', 9681), ('and', 1613), ('top', 24125), ('it', 12752), ('off', 16455), ('get', 10439), ('room', 20285), ('reserved', 19800), ('they', 23775), ('said', 20510), ('someone', 22056), ('had', 11034), ('been', 2915), ('smoking', 21865), ('in', 12200), ('so', 21941), ('use', 25171), ('got', 10661), ('different', 7051), ('wont', 26487), ('be', 2822), ('staying', 22598), ('there', 23760), ('anymore', 1791), ('stayed', 22594), ('this', 23801), ('hotel', 11756), ('while', 26276), ('visiting', 25716), ('my', 15698), ('son', 22076), ('at', 2195), ('west', 26217), ('point', 17981), ('was', 26006), ('very', 25562), ('concerned', 5494), ('with', 26427), ('parking', 17157), ('back', 2521), ('between', 3154), ('woods', 26493), ('uncomfortable', 24796), ('leaving', 13739), ('rental', 19668), ('car', 4241), ('out', 16815), ('smelled', 21833), ('like', 13940), ('smoke', 21855), ('even', 8693), ('though', 23818), ('asked', 2116), ('nonsmoking', 16153), ('arrived', 2044), ('elevator', 8100), ('broken', 3751), ('wife', 26340), ('has', 11198), ('bad', 2541), ('knee', 13337), ('we', 26096), ('climb', 5034), ('two', 24657), ('flights', 9550), ('stairs', 22503), ('third', 23798), ('floor', 9568), ('our', 16809), ('offered', 16465), ('help', 11370), ('us', 25156), ('carry', 4320), ('luggage', 14320), ('or', 16685), ('provided', 18620), ('any', 1787), ('type', 24664), ('amenities', 1531), ('inconvenience', 12271), ('not', 16200), ('what', 26241), ('expected', 8869), ('from', 9980), ('la', 13488), ('quinta', 18917), ('property', 18563), ('is', 12720), ('second', 20931), ('time', 23948), ('have', 11240), ('that', 23721), ('quality', 18816), ('service', 21150), ('great', 10771), ('both', 3525), ('visits', 25720), ('clean', 4976), ('staff', 22476), ('friendly', 9950), ('helpful', 11373), ('actually', 1011), ('did', 7019), ('surprised', 23146), ('variety', 25361), ('lady', 13514), ('works', 26520), ('area', 1968), ('greeted', 10794), ('more', 15468), ('waiting', 25910), ('areas', 1969), ('no', 16098), ('air', 1262), ('flow', 9591), ('always', 1487), ('hot', 11749), ('stagnet', 22489), ('challenge', 4556), ('alwys', 1489), ('ahd', 1226), ('taxi', 23481), ('but', 3981), ('guests', 10934), ('over', 16864), ('cleanliness', 4987), ('lacking', 13501), ('dirty', 7159), ('windows', 26372), ('hallway', 11069), ('mirrors', 15229), ('dusty', 7816), ('spotted', 22380), ('wasn', 26025), ('vacuumed', 25271), ('well', 26177), ('etc', 8643), ('utter', 25239), ('disrepair', 7316), ('literally', 14037), ('falling', 9074), ('apart', 1811), ('impression', 12176), ('some', 22052), ('rooms', 20297), ('used', 25175), ('low', 14277), ('income', 12253), ('long', 14186), ('term', 23636), ('housing', 11820), ('called', 4102), ('security', 20952), ('exit', 8850), ('propped', 18576), ('open', 16631), ('door', 7494), ('next', 16002), ('mine', 15170), ('uncleaned', 24791), ('vacant', 25255), ('wings', 26389), ('storts', 22750), ('bar', 2658), ('location', 14128), ('ideal', 12033), ('close', 5061), ('strand', 22774), ('bus', 3950), ('stop', 22725), ('on', 16584), ('block', 3348), ('free', 9860), ('shuttle', 21445), ('goes', 10606), ('up', 25080), ('down', 7561), ('king', 13272), ('st', 22457), ('everything', 8713), ('by', 4012), ('you', 26706), ('can', 4158), ('walk', 25931), ('if', 12060), ('don', 7470), ('want', 25967), ('wait', 25905), ('only', 16601), ('negative', 15887), ('could', 5965), ('hear', 11296), ('every', 8706), ('sound', 22138), ('outside', 16848), ('traveling', 24371), ('myself', 15705), ('maybe', 14813), ('wouldn', 26548), ('noticed', 16219), ('noise', 16122), ('much', 15606),  ...

# %%
vocabulary
# Out:
# ['00',
#  '000',
#  '0000',
#  '0002',
#  '00am',
#  '00dcopxqg',
#  '00dollar',
#  '00n',
#  '00p',
#  '00pm',
#  '01',
#  '02',
#  '0200',
#  '03',
#  '0300am',
#  '0330',
#  '03am',
#  '03mbps',
#  '04',
#  '0400',
#  '05',
#  '054',
#  '0555',
#  '05h30',
#  '06',
#  '0600',
#  '07',
#  '08',
#  '0815',
#  '0830',
#  '09',
#  '0930',
#  '0ne',
#  '10',
#  '100',
#  '1000',
#  '10000rp',
#  '1000am',
#  '1008',
#  '100m',
#  '100mb',
#  '100not',
#  '100x',
#  '101',
#  '1013',
#  '1015',
#  '102',
#  '1020',
#  '103',
#  '1030',
#  '1030am',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '10a',
#  '10am',
#  '10dollars',
#  '10euros',
#  '10gg',
#  '10ish',
#  '10miles',
#  '10min',
#  '10minutes',
#  '10mn',
#  '10p',
#  '10pm',
#  '10th',
#  '10x',
#  '10yerars',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '1130am',
#  '1130pm',
#  '114was',
#  '115',
#  '116',
#  '1161',
#  '117',
#  '118',
#  '119',
#  '11am',
#  '11amwe',
#  '11hour',
#  '11ieme',
#  '11ish',
#  '11p',
#  '11pm',
#  '11th',
#  '11v',
#  '11y',
#  '11yo',
#  '12',
#  '120',
#  '1200',
#  '1200pm',
#  '121',
#  '122',
#  '123',
#  '1230',
#  '1230am',
#  '124',
#  '125',
#  '126',
#  '127',
#  '1278',
#  '128',
#  '129',
#  '12am',
#  '12h',
#  '12hrs',
#  '12m',
#  '12noon',
#  '12pm',
#  '12th',
#  '12x16',
#  '13',
#  '130',
#  '1300',
#  '130am',
#  '131',
#  '132',
#  '133',
#  '135',
#  '136',
#  '13651',
#  '138',
#  '139',
#  '13a',
#  '13h',
#  '13th',
#  '13years',
#  '14',
#  '140',
#  '1400',
#  '142',
#  '1422',
#  '144',
#  '145',
#  '146',
#  '148',
#  '149',
#  '14th',
#  '15',
#  '150',
#  '150e',
#  '150lbs',
#  '151',
#  '152',
#  '1522',
#  '155',
#  '158',
#  '159',
#  '15am',
#  '15dollar',
#  '15euros',
#  '15min',
#  '15mintues',
#  '15p',
#  '15pm',
#  '15th',
#  '16',
#  '160',
#  '1600',
#  '1604',
#  '1606',
#  '1622',
#  '164',
#  '166',
#  '167',
#  '168',
#  '169',
#  '16h',
#  '16th',
#  '17',
#  '170',
#  '1700',
#  '1700s',
#  '172',
#  '1730',
#  '175',
#  '177',
#  '178',
#  '1785',
#  '179',
#  '17h',
#  '17most',
#  '17th',
#  '18',
#  '180',
#  '1800',
#  '181',
#  '1812',
#  '182',
#  '1822',
#  '183',
#  '1830',
#  '1833',
#  '1840',
#  '185',
#  '1850s',
#  '188',
#  '1880',
#  '1887',
#  '189',
#  '1895',
#  '18ft',
#  '18mo',
#  '18th',
#  '19',
#  '190',
#  '1900',
#  '1906',
#  '1909',
#  '1920',
#  '1920s',
#  '1926',
#  '1930',
#  '1930s',
#  '1931',
#  '1939',
#  '194',
#  '1940',
#  '1940s',
#  '1946',
#  '195',
#  '1950',
#  '1952',
#  '1954',
#  '1955',
#  '1960',
#  '1960s',
#  '1968',
#  '1970',
#  '1970s',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1979',
#  '1980',
#  '1980s',
#  '1981',
#  '1984',
#  '1985',
#  '1988',
#  '199',
#  '1990',
#  '1992',
#  '1993',
#  '1995',
#  '1996',
#  '1999',
#  '19h',
#  '19th',
#  '1am',
#  '1bed',
#  '1bedrooms',
#  '1er',
#  '1era',
#  '1full',
#  '1h',
#  '1h00',
#  '1hr',
#  '1k',
#  '1mbps',
#  '1n',
#  '1night',
#  '1p',
#  '1pm',
#  '1re',
#  '1s',
#  '1set',
#  '1st',
#  '1to',
#  '1week',
#  '1x',
#  '20',
#  '200',
#  '2000',
#  '2000s',
#  '2001',
#  '20010',
#  '2002',
#  '2003',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '201',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2015and',
#  '2016',
#  '2017',
#  '2019',
#  '202',
#  '203',
#  '204',
#  '205',
#  '206',
#  '208',
#  '209',
#  '20am',
#  '20e',
#  '20kg',
#  '20lbs',
#  '20m',
#  '20min',
#  '20mins',
#  '20minute',
#  '20minutes',
#  '20mn',
#  '20pm',
#  '20s',
#  '20th',
#  '20yrs',
#  '20분',
#  '21',
#  '210',
#  '211',
#  '2111',
#  '213',
#  '214',
#  '215',
#  '216',
#  '218',
#  '219',
#  '21st',
#  '22',
#  '220',
#  '221',
#  '222',
#  '223',
#  '224',
#  '225',
#  '227',
#  '228',
#  '229',
#  '22nd',
#  '23',
#  '2300hrs',
#  '230am',
#  '230pm',
#  '233',
#  '236',
#  '237',
#  '238',
#  '23fx',
#  '23rd',
#  '24',
#  '240',
#  '240lbs',
#  '241',
#  '242',
#  '249',
#  '24h',
#  '24hours',
#  '24hoursofbooty',
#  '24hr',
#  '24hrs',
#  '24mb',
#  '24th',
#  '25',
#  '250',
#  '250e',
#  '253',
#  '25am',
#  '25min',
#  '25mph',
#  '25n',
#  '25p',
#  '25th',
#  '25w',
#  '26',
#  '260',
#  '2600',
#  '262',
#  '265',
#  '268',
#  '26th',
#  '27',
#  '270',
#  '274',
#  '278',
#  '279',
#  '27th',
#  '28',
#  '280',
#  '281',
#  '289',
#  '28th',
#  '29',
#  '290',
#  '2900',
#  '29euros',
#  '29th',
#  '2adultes',
#  '2am',
#  '2ans',
#  '2ba',
#  '2br',
#  '2days',
#  '2h',
#  '2h00',
#  '2km',
#  '2mal',
#  '2mi',
#  '2min',
#  '2nd',
#  '2of',
#  '2pm',
#  '2star',
#  '2tvs',
#  '2x',
#  '2x3ft',
#  '2x4',
#  '2yrs',
#  '30',
#  '300',
#  '301',
#  '3014',
#  '303',
#  '305',
#  '3072',
#  '308',
#  '309',
#  '30a',
#  '30am',
#  '30c',
#  '30min',
#  '30mins',
#  '30p',
#  '30pm',
#  '30th',
#  '31',
#  '3102',
#  '311',
#  '313',
#  '314',
#  '315pn',
#  '31st',
#  '32',
#  '320',
#  '329',
#  '33',
#  '330am',
#  '333',
#  '334740612',
#  '335',
#  '336',
#  '34',
#  '347',
#  '34th',
#  '35',
#  '350',
#  '356514',
#  '35th',
#  '36',
#  '360',
#  '37',
#  '370',
#  '372',
#  '38',
#  '380',
#  '385',
#  '39',
#  '3am',
#  '3ft',
#  '3me',
#  '3mornings',
#  '3nuits',
#  '3pm',
#  '3rd',
#  '3rs',
#  '3times',
#  '3uger',
#  '3x',
#  '3x3',
#  '3yr',
#  '3分の場所でも',
#  '40',
#  '400',
#  '405',
#  '406',
#  '407',
#  '408',
#  '40b',
#  '40berkeley',
#  '40km',
#  '40min',
#  '40s',
#  '40th',
#  '410',
#  '411',
#  '412',
#  '416',
#  '417',
#  '418',
#  '41st',
#  '42',
#  '42397',
#  '428',
#  '42inch',
#  '43',
#  '44',
#  '444',
#  '445',
#  '4480',
#  '449',
#  '44euros',
#  '45',
#  '450',
#  '45am',
#  '45min',
#  '45mins',
#  '45pm',
#  '45th',
#  '46',
#  '465',
#  '46th',
#  '47',
#  '475',
#  '48',
#  '48th',
#  '49',
#  '497',
#  '4a',
#  '4am',
#  '4b',
#  '4c',
#  '4g',
#  '4h',
#  '4hrs',
#  '4jahreszeiten',
#  '4me',
#  '4month',
#  '4pm',
#  '4th',
#  '4u',
#  '4yr',
#  '50',
#  '500',
#  '5000',
#  '5001a19grvb',
#  '500m',
#  '500meters',
#  '500th',
#  '502',
#  '505',
#  '506',
#  '50am',
#  '50ft',
#  '50k',
#  '50m',
#  '50pm',
#  '50s',
#  '50th',
#  '51',
#  '516',
#  '52',
#  '524',
#  '526',
#  '53',
#  '54',
#  '540',
#  '545',
#  '55',
#  '550',
#  '55am',
#  '55th',
#  '55tl',
#  '56',
#  '56k',
#  '57',
#  '58',
#  '580',
#  '59',
#  '595',
#  '598',
#  '5a',
#  '5am',
#  '5h',
#  '5k',
#  '5me',
#  '5miles',
#  '5min',
#  '5minutes',
#  '5p',
#  '5person',
#  '5pm',
#  '5star',
#  '5stars',
#  '5th',
#  '60',
#  '600',
#  '606',
#  '60aus',
#  '60iger',
#  '60s',
#  '60th',
#  '615',
#  '62',
#  '63',
#  '64',
#  '645',
#  '65',
#  '651',
#  '657',
#  '65p',
#  '66',
#  '664',
#  '66th',
#  '68',
#  '6860',
#  '69',
#  '6a',
#  '6am',
#  '6g9cff',
#  '6h',
#  '6hours',
#  '6ijx3b',
#  '6l',
#  '6oz',
#  '6p',
#  '6pm',
#  '6th',
#  '6x',
#  '6yr',
#  '70',
#  '700',
#  '70000',
#  '701',
#  '702',
#  '704',
#  '705',
#  '707',
#  '70s',
#  '70th',
#  '72',
#  '722',
#  '727',
#  '727taxi',
#  '73',
#  '730',
#  '733',
#  '74',
#  '747',
#  '75',
#  '750',
#  '75day',
#  '75th',
#  '75yr',
#  '76',
#  '77',
#  '78',
#  '79',
#  '7a',
#  '7am',
#  '7days',
#  '7mgps',
#  '7p',
#  '7pm',
#  '7saty',
#  '7th',
#  '80',
#  '800',
#  '8000',
#  '801',
#  '805',
#  '80s',
#  '80th',
#  '81',
#  '811',
#  '82',
#  '8294',
#  '83',
#  '830ish',
#  '83rd',
#  '84',
#  '847',
#  '85',
#  '85th',
#  '86',
#  '87',
#  '88',
#  '89',
#  '8am',
#  '8ish',
#  '8mbps',
#  '8miles',
#  '8min',
#  '8p',
#  '8pm',
#  '8s',
#  '8th',
#  '90',
#  '900',
#  '9000rp',
#  '90cents',
#  '90s',
#  '90th',
#  '91',
#  '910',
#  '915',
#  '917',
#  '92',
#  '920',
#  '93',
#  '930',
#  '930pm',
#  '94',
#  '95',
#  '96',
#  '97',
#  '98',
#  '99',
#  '9am',
#  '9h1',
#  '9pm',
#  '9th',
#  '_at',
#  'a1',
#  'a10',
#  'a1a',
#  'a25',
#  'a44',
#  'a5',
#  'a7',
#  'aa',
#  'aaa',
#  'aaaahh',
#  'aafter',
#  'aamiainen',
#  'aamupala',
#  'aan',
#  'aanrader',
#  'aanwinst',
#  'aarp',
#  'ab',
#  'aback',
#  'abandonado',
#  'abandoned',
#  'abanico',
#  'abbastanza',
#  'abbey',
#  'abbiamo',
#  'abbiano',
#  'abbigliamento',
#  'abbondante',
#  'abbott',
#  'abc',
#  'abd',
#  'abend',
#  'abendbuffet',
#  'abendessen',
#  'abends',
#  'abenteuer',
#  'aber',
#  'aberdeen',
#  'abfallprodukte',
#  'abgebaut',
#  'abgenommen',
#  'abgenutzt',
#  'abgestorbene',
#  'abgewohnt',
#  'abgewohntes',
#  'abides',
#  'abiertos',
#  'abilene',
#  'abilities',
#  'ability',
#  'abit',
#  'abita',
#  'abitacion',
#  'abiver',
#  'able',
#  'abmi',
#  'abo',
#  'aboard',
#  'abode',
#  'abondante',
#  'abordable',
#  'abound',
#  'abounds',
#  'about',
#  'above',
#  'abrasive',
#  'abre',
#  'abriera',
#  'abroad',
#  'abrumen',
#  'abrupt',
#  'abruptly',
#  'abs',
#  'absacker',
#  'abseits',
#  'absence',
#  'absense',
#  'absent',
#  'absolument',
#  'absolumment',
#  'absolut',
#  'absolute',
#  'absolutely',
#  'absolutes',
#  'absolutley',
#  'absolutly',
#  'absorb',
#  'absorbed',
#  'absorbent',
#  'abstrich',
#  'absurd',
#  'absurdly',
#  'abt',
#  'abundance',
#  'abundant',
#  'aburrido',
#  'abuse',
#  'abusif',
#  'abuts',
#  'abv',
#  'abvi',
#  'abwechslung',
#  'abwicklung',
#  'abysmal',
#  'abysmally',
#  'abzug',
#  'ac',
#  'acabo',
#  'acabou',
#  'academy',
#  'acadia',
#  'acapulco',
#  'acazaba',
#  'accade',
#  'accademia',
#  'accder',
#  'accecptable',
#  'acceder',
#  'accelerated',
#  'accent',
#  'accents',
#  'accept',
#  'acceptable',
#  'acceptably',
#  'accepted',
#  'accepting',
#  'accepts',
#  'acces',
#  'accesible',
#  'acceso',
#  'accesories',
#  'access',
#  'accessable',
#  'accessed',
#  'accesses',
#  'accessibility',
#  'accessible',
#  'accessibles',
#  'accessing',
#  'accessoires',
#  'accessories',
#  'acceuil',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidently',
#  'accidents',
#  'accmodating',
#  'accogliente',
#  'accoglienza',
#  'accomadate',
#  'accomadated',
#  'accomadating',
#  'accomadations',
#  'accomdated',
#  'accomdating',
#  'accomedated',
#  'accomedating',
#  'accomendations',
#  'accomidating',
#  'accomindate',
#  'accomindations',
#  'accommodate',
#  'accommodated',
#  'accommodates',
#  'accommodatig',
#  'accommodating',
#  'accommodation',
#  'accommodations',
#  'accomodate',
#  'accomodated',
#  'accomodating',
#  'accomodation',
#  'accomodations',
#  'accompagn',
#  'accompanied',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'accomplishment',
#  'accor',
#  'accord',
#  'according',
#  'accordingly',
#  'accosted',
#  'accosting',
#  'account',
#  'accountable',
#  'accounted',
#  'accounts',
#  'accoutrements',
#  'accroutrements',
#  'accrued',
#  'accs',
#  'accueil',
#  'accueilants',
#  'accueillant',
#  'accueilli',
#  'accumulated',
#  'accumulates',
#  'accumulating',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accusation',
#  'accused',
#  'accusing',
#  'accustomed',
#  'acdc',
#  'ace',
#  'aces',
#  'acess',
#  'acesso',
#  'acessvel',
#  'ach',
#  'achalands',
#  'achamos',
#  'ache',
#  'achei',
#  'aches',
#  'acheter',
#  'achieves',
#  'aching',
#  'acho',
#  'achy',
#  'acid',
#  'acidity',
#  'acknowledge',
#  'acknowledged',
#  'acknowledgement',
#  'acogedor',
#  'acogedora',
#  'acolhedor',
#  'acomadating',
#  'acomadation',
#  'acommodating',
#  'acomoda',
#  'acomodaes',
#  'acomodar',
#  'acomodation',
#  'acompanhar',
#  'aconchegante',
#  'acondicionado',
#  'aconsejo',
#  'acorde',
#  'acordes',
#  'acordo',
#  'acouple',
#  'acoustic',
#  'acoustics',
#  'acoverted',
#  'acqua',
#  'acquainted',
#  'acquired',
#  'acres',
#  'acros',
#  'across',
#  'acrossed',
#  'acs',
#  'acstico',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'actions',
#  'actitud',
#  'activated',
#  'activates',
#  ...]

# %%
model=DecisionTreeClassifier(max_depth=6,min_samples_split=10)
         
model.fit(counts_train, train_labels)

pred=model.predict(counts_test)

accuracy_score(test_labels,pred)
# Out:
# 0.6943986020774682

# %%
model.classes_
# Out:
# array(['avg', 'neg', 'pos'], dtype=object)

# %%
plt.figure(figsize=(20,20))  # set plot size (denoted in inches)

tree.plot_tree(model, 
               max_depth=4,
               filled=True, 
               impurity=False, 
               fontsize=10, 
               feature_names=vocabulary)

plt.savefig('tree.png',format='png',bbox_inches = "tight")

# %% [markdown]
# <h2> Medical Diagnosis </h2>

# %%
med=pd.read_csv('medical/medical_data.csv')

# %%
train_data, test_data = train_test_split(med, test_size=0.3)

train_symptoms=train_data.drop(columns=['diagnosis'])
train_labels=train_data['diagnosis']               
    
test_symptoms=test_data.drop(columns=['diagnosis'])
test_labels=test_data['diagnosis']

# %%
train_symptoms
# Out:
#       fever  cough  tiredness  headache  stuffy nose  runny nose  sneezing  \
# 1102      0      0          0         0            1           0         1
# 125       1      1          1         0            0           0         0
# 873       1      1          0         1            1           1         0
# 340       0      0          1         0            0           0         0
# 176       1      1          1         0            0           0         0
# ...     ...    ...        ...       ...          ...         ...       ...
# 657       1      1          1         0            1           0         0
# 1408      0      0          0         0            1           1         0
# 1436      0      0          0         0            1           1         1
# 1033      0      0          0         0            1           1         1
# 508       1      0          1         1            0           0         0
#
#       sore throat
# 1102            0
# 125             0
# 873             1
# 340             0
# 176             0
# ...           ...
# 657             1
# 1408            0
# 1436            0
# 1033            0
# 508             1
#
# [1400 rows x 8 columns]

# %%
model=MultinomialNB()

model.fit(train_symptoms,train_labels)

pred=model.predict(test_symptoms)

accuracy_score(test_labels,pred)
# Out:
# 0.8316666666666667

# %%
model.classes_
# Out:
# array(['allergies', 'common cold', 'covid19', 'flu'], dtype=object)

# %%
plt.figure(figsize=(12,12))  # set plot size (denoted in inches)

tree.plot_tree(model, 
               max_depth=2,
               filled=True, 
               impurity=False, 
               fontsize=10, 
               feature_names=train_symptoms.columns)

plt.savefig('tree.png',format='png',bbox_inches = "tight")
